# %%
import numpy as np
import matplotlib.pyplot as plt

p0 = np.loadtxt("p0.txt")

t_array = p0[:,0]
p0_x = p0[:,1]
p0_y = p0[:,2]
p0_z = p0[:,3]


plt.figure()
plt.plot(p0_x, p0_y)
plt.show()

# %%
p0
# Out:
# array([[ 0.00000000e+00,  4.99005000e+02,  0.00000000e+00,
#          0.00000000e+00],
#        [ 8.64000000e+04,  4.98931168e+02,  8.58367214e+00,
#          0.00000000e+00],
#        [ 1.72800000e+05,  4.98709695e+02,  1.71648042e+01,
#          0.00000000e+00],
#        ...,
#        [ 3.12768000e+07,  4.98225335e+02, -2.78837791e+01,
#          0.00000000e+00],
#        [ 3.13632000e+07,  4.98631264e+02, -1.93093928e+01,
#          0.00000000e+00],
#        [ 3.14496000e+07,  4.98889639e+02, -1.07292925e+01,
#          0.00000000e+00]])

# %%
t_array = p0[:,0]
p0_x = p0[:,1]
p0_y = p0[:,2]
p0_z = p0[:,3]
